# %% [markdown]
# Imports

# %%
from model import Forecast, FitPredict, Evaluation
from process_data import PreProcessData, PostProcessData

import pandas as pd
import random

# %% [markdown]
# Load datasets

# %%
df_train = PreProcessData.train
df_test = PreProcessData.test

# %%
forecast = Forecast()
fit_predict = FitPredict()
evaluator = Evaluation()
preprocessor = PreProcessData(df_train, df_test)
postprocessor = PostProcessData()

# %% [markdown]
# Load models

# %%
lgbm = forecast.create_lgbm_regressor_forecaster
svr = forecast.create_svr_regresor_forecaster
forest = forecast.create_random_forest_regresor_forecaster
sarimax = forecast.create_sarimax_forecaster

# %%
model_list = [lgbm, svr, forest, sarimax]

# %%
name_models = {lgbm:'lgbm', forest:'forest', svr:'svr', sarimax:'sarimax'}

# %% [markdown]
# Fit models

# %%
df_dic = preprocessor.clean_dic
dic_sample = random.choice(list(df_dic.values()))
train_sample, test_sample = dic_sample[0], dic_sample[1]
steps = len(test_sample)
y_column = 'num_sold'

# %%
df_to_2ndmodel = [('Singapore','Premium Sticker Mart','Kaggle'),
('Norway','Premium Sticker Mart','Kerneler'),
('Norway','Premium Sticker Mart','Kaggle Tiers'),
('Norway','Premium Sticker Mart','Kaggle'),
('Norway','Premium Sticker Mart','Holographic Goose'),
('Norway','Stickers for Less','Kerneler Dark Mode'),
('Norway','Stickers for Less','Kerneler'),
('Norway','Stickers for Less','Kaggle Tiers'),
('Norway','Stickers for Less','Kaggle'),
('Norway','Stickers for Less','Holographic Goose'),
('Norway','Discount Stickers','Kerneler'),
('Norway','Discount Stickers','Kaggle Tiers'),
('Norway','Discount Stickers','Kaggle'),
('Norway','Discount Stickers','Holographic Goose'),
('Italy','Premium Sticker Mart','Kaggle Tiers'),
('Italy','Premium Sticker Mart','Kaggle'),
('Italy','Stickers for Less','Kaggle Tiers'),
('Italy','Stickers for Less','Kaggle'),
('Italy','Discount Stickers','Kaggle Tiers'),
('Italy','Discount Stickers','Kaggle'),
('Finland','Premium Sticker Mart','Kaggle Tiers'),
('Finland','Premium Sticker Mart','Kaggle'),
('Finland','Stickers for Less','Kaggle Tiers'),
('Finland','Stickers for Less','Kaggle'),
('Finland','Discount Stickers','Kaggle Tiers'),
('Finland','Discount Stickers','Kaggle'),
('Canada','Premium Sticker Mart','Kaggle Tiers'),
('Canada','Premium Sticker Mart','Kaggle'),
('Canada','Stickers for Less','Kaggle Tiers'),
('Canada','Stickers for Less','Kaggle' ),
('Canada','Stickers for Less','Holographic Goose'),
('Canada','Discount Stickers','Kaggle Tiers'),
('Canada','Discount Stickers','Kaggle')]

# %%
submission = pd.DataFrame()
counter = 0
for key, value in df_dic.items():
    counter += 1
    print(counter)
    if key not in df_to_2ndmodel:
        forecaster = forest(steps)
        print(key)
        fit_predict.fit_forecaster(forecaster, value[0], y_column )
        predictions = fit_predict.get_predictions(forecaster, steps)
        test_w_preds = pd.concat([value[1], predictions], axis=1).rename(columns={'pred':'num_sold'})
        submission = pd.concat([submission, test_w_preds])
        submission = submission.reset_index()[['id', 'num_sold']].sort_values('id')
        print(f'submission_updated for {key}')
    if key in df_to_2ndmodel:
        forecaster = lgbm(steps)
        print(key)
        fit_predict.fit_forecaster(forecaster, value[0], y_column )
        predictions = fit_predict.get_predictions(forecaster, steps)
        test_w_preds = pd.concat([value[1], predictions], axis=1).rename(columns={'pred':'num_sold'})
        submission = pd.concat([submission, test_w_preds])
        submission = submission.reset_index()[['id', 'num_sold']].sort_values('id')
        print(f'submission_updated for {key} hyperparameter')
submission.to_csv('submission_20250128_au_hyper.csv', index=False)
print('submission_saved')
# Out:
# 1
# ('Canada', 'Discount Stickers', 'Holographic Goose')
# submission_updated for ('Canada', 'Discount Stickers', 'Holographic Goose')
# 2
# ('Canada', 'Discount Stickers', 'Kaggle')
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.028682 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 279083
# [LightGBM] [Info] Number of data points in the train set: 1462, number of used features: 1095
# [LightGBM] [Info] Start training from score 699.651163
# submission_updated for ('Canada', 'Discount Stickers', 'Kaggle') hyperparameter
# 3
# ('Canada', 'Discount Stickers', 'Kaggle Tiers')
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.032654 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 278959
# [LightGBM] [Info] Number of data points in the train set: 1462, number of used features: 1095
# [LightGBM] [Info] Start training from score 577.499316
# submission_updated for ('Canada', 'Discount Stickers', 'Kaggle Tiers') hyperparameter
# 4
# ('Canada', 'Discount Stickers', 'Kerneler')
# submission_updated for ('Canada', 'Discount Stickers', 'Kerneler')
# 5
# ('Canada', 'Discount Stickers', 'Kerneler Dark Mode')
# submission_updated for ('Canada', 'Discount Stickers', 'Kerneler Dark Mode')
# 6
# ('Canada', 'Premium Sticker Mart', 'Holographic Goose')
# submission_updated for ('Canada', 'Premium Sticker Mart', 'Holographic Goose')
# 7
# ('Canada', 'Premium Sticker Mart', 'Kaggle')
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.025669 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 279225
# [LightGBM] [Info] Number of data points in the train set: 1462, number of used features: 1095
# [LightGBM] [Info] Start training from score 1670.731874
# submission_updated for ('Canada', 'Premium Sticker Mart', 'Kaggle') hyperparameter
# 8
# ('Canada', 'Premium Sticker Mart', 'Kaggle Tiers')
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.026222 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 279225
# [LightGBM] [Info] Number of data points in the train set: 1462, number of used features: 1095
# [LightGBM] [Info] Start training from score 1378.255814
# submission_updated for ('Canada', 'Premium Sticker Mart', 'Kaggle Tiers') hyperparameter
# 9
# ('Canada', 'Premium Sticker Mart', 'Kerneler')
# submission_updated for ('Canada', 'Premium Sticker Mart', 'Kerneler')
# 10
# ('Canada', 'Premium Sticker Mart', 'Kerneler Dark Mode')
# submission_updated for ('Canada', 'Premium Sticker Mart', 'Kerneler Dark Mode')
# 11
# ('Canada', 'Stickers for Less', 'Holographic Goose')
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.017014 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 106653
# [LightGBM] [Info] Number of data points in the train set: 1462, number of used features: 1095
# [LightGBM] [Info] Start training from score 220.835841
# submission_updated for ('Canada', 'Stickers for Less', 'Holographic Goose') hyperparameter
# 12
# ('Canada', 'Stickers for Less', 'Kaggle')
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.025910 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 279225
# [LightGBM] [Info] Number of data points in the train set: 1462, number of used features: 1095
# [LightGBM] [Info] Start training from score 1417.731190
# submission_updated for ('Canada', 'Stickers for Less', 'Kaggle') hyperparameter
# 13
# ('Canada', 'Stickers for Less', 'Kaggle Tiers')
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.027990 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 279225
# [LightGBM] [Info] Number of data points in the train set: 1462, number of used features: 1095
# [LightGBM] [Info] Start training from score 1166.454172
# submission_updated for ('Canada', 'Stickers for Less', 'Kaggle Tiers') hyperparameter
# 14
# ('Canada', 'Stickers for Less', 'Kerneler')
# submission_updated for ('Canada', 'Stickers for Less', 'Kerneler')
# 15
# ('Canada', 'Stickers for Less', 'Kerneler Dark Mode')
# submission_updated for ('Canada', 'Stickers for Less', 'Kerneler Dark Mode')
# 16
# ('Finland', 'Discount Stickers', 'Holographic Goose')
# submission_updated for ('Finland', 'Discount Stickers', 'Holographic Goose')
# 17
# ('Finland', 'Discount Stickers', 'Kaggle')
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.026003 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 279225
# [LightGBM] [Info] Number of data points in the train set: 1462, number of used features: 1095
# [LightGBM] [Info] Start training from score 698.030096
# submission_updated for ('Finland', 'Discount Stickers', 'Kaggle') hyperparameter
# 18
# ('Finland', 'Discount Stickers', 'Kaggle Tiers')
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.025182 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 279032
# [LightGBM] [Info] Number of data points in the train set: 1462, number of used features: 1095
# [LightGBM] [Info] Start training from score 576.092339
# submission_updated for ('Finland', 'Discount Stickers', 'Kaggle Tiers') hyperparameter
# 19
# ('Finland', 'Discount Stickers', 'Kerneler')
# submission_updated for ('Finland', 'Discount Stickers', 'Kerneler')
# 20
# ('Finland', 'Discount Stickers', 'Kerneler Dark Mode')
# submission_updated for ('Finland', 'Discount Stickers', 'Kerneler Dark Mode')
# 21
# ('Finland', 'Premium Sticker Mart', 'Holographic Goose')
# submission_updated for ('Finland', 'Premium Sticker Mart', 'Holographic Goose')
# 22
# ('Finland', 'Premium Sticker Mart', 'Kaggle')
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.033305 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 279225
# [LightGBM] [Info] Number of data points in the train set: 1462, number of used features: 1095
# [LightGBM] [Info] Start training from score 1672.595075
# submission_updated for ('Finland', 'Premium Sticker Mart', 'Kaggle') hyperparameter
# 23
# ('Finland', 'Premium Sticker Mart', 'Kaggle Tiers')
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.025193 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 279225
# [LightGBM] [Info] Number of data points in the train set: 1462, number of used features: 1095
# [LightGBM] [Info] Start training from score 1371.049248
# submission_updated for ('Finland', 'Premium Sticker Mart', 'Kaggle Tiers') hyperparameter
# 24
# ('Finland', 'Premium Sticker Mart', 'Kerneler')
# submission_updated for ('Finland', 'Premium Sticker Mart', 'Kerneler')
# 25
# ('Finland', 'Premium Sticker Mart', 'Kerneler Dark Mode')
# submission_updated for ('Finland', 'Premium Sticker Mart', 'Kerneler Dark Mode')
# 26
# ('Finland', 'Stickers for Less', 'Holographic Goose')
# submission_updated for ('Finland', 'Stickers for Less', 'Holographic Goose')
# 27
# ('Finland', 'Stickers for Less', 'Kaggle')
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.023820 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 279225
# [LightGBM] [Info] Number of data points in the train set: 1462, number of used features: 1095
# [LightGBM] [Info] Start training from score 1412.516416
# submission_updated for ('Finland', 'Stickers for Less', 'Kaggle') hyperparameter
# 28
# ('Finland', 'Stickers for Less', 'Kaggle Tiers')
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.025358 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 279225
# [LightGBM] [Info] Number of data points in the train set: 1462, number of used features: 1095
# [LightGBM] [Info] Start training from score 1163.205198
# submission_updated for ('Finland', 'Stickers for Less', 'Kaggle Tiers') hyperparameter
# 29
# ('Finland', 'Stickers for Less', 'Kerneler')
# submission_updated for ('Finland', 'Stickers for Less', 'Kerneler')
# 30
# ('Finland', 'Stickers for Less', 'Kerneler Dark Mode')
# submission_updated for ('Finland', 'Stickers for Less', 'Kerneler Dark Mode')
# 31
# ('Italy', 'Discount Stickers', 'Holographic Goose')
# submission_updated for ('Italy', 'Discount Stickers', 'Holographic Goose')
# 32
# ('Italy', 'Discount Stickers', 'Kaggle')
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.030273 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 266294
# [LightGBM] [Info] Number of data points in the train set: 1462, number of used features: 1095
# [LightGBM] [Info] Start training from score 491.063611
# submission_updated for ('Italy', 'Discount Stickers', 'Kaggle') hyperparameter
# 33
# ('Italy', 'Discount Stickers', 'Kaggle Tiers')
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.026165 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 234617
# [LightGBM] [Info] Number of data points in the train set: 1462, number of used features: 1095
# [LightGBM] [Info] Start training from score 405.246922
# submission_updated for ('Italy', 'Discount Stickers', 'Kaggle Tiers') hyperparameter
# 34
# ('Italy', 'Discount Stickers', 'Kerneler')
# submission_updated for ('Italy', 'Discount Stickers', 'Kerneler')
# 35
# ('Italy', 'Discount Stickers', 'Kerneler Dark Mode')
# submission_updated for ('Italy', 'Discount Stickers', 'Kerneler Dark Mode')
# 36
# ('Italy', 'Premium Sticker Mart', 'Holographic Goose')
# submission_updated for ('Italy', 'Premium Sticker Mart', 'Holographic Goose')
# 37
# ('Italy', 'Premium Sticker Mart', 'Kaggle')
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.027095 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 279225
# [LightGBM] [Info] Number of data points in the train set: 1462, number of used features: 1095
# [LightGBM] [Info] Start training from score 1177.623119
# submission_updated for ('Italy', 'Premium Sticker Mart', 'Kaggle') hyperparameter
# 38
# ('Italy', 'Premium Sticker Mart', 'Kaggle Tiers')
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.029590 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 279225
# [LightGBM] [Info] Number of data points in the train set: 1462, number of used features: 1095
# [LightGBM] [Info] Start training from score 969.359781
# submission_updated for ('Italy', 'Premium Sticker Mart', 'Kaggle Tiers') hyperparameter
# 39
# ('Italy', 'Premium Sticker Mart', 'Kerneler')
# submission_updated for ('Italy', 'Premium Sticker Mart', 'Kerneler')
# 40
# ('Italy', 'Premium Sticker Mart', 'Kerneler Dark Mode')
# submission_updated for ('Italy', 'Premium Sticker Mart', 'Kerneler Dark Mode')
# 41
# ('Italy', 'Stickers for Less', 'Holographic Goose')
# submission_updated for ('Italy', 'Stickers for Less', 'Holographic Goose')
# 42
# ('Italy', 'Stickers for Less', 'Kaggle')
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.024488 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 279225
# [LightGBM] [Info] Number of data points in the train set: 1462, number of used features: 1095
# [LightGBM] [Info] Start training from score 997.264706
# submission_updated for ('Italy', 'Stickers for Less', 'Kaggle') hyperparameter
# 43
# ('Italy', 'Stickers for Less', 'Kaggle Tiers')
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.025844 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 279223
# [LightGBM] [Info] Number of data points in the train set: 1462, number of used features: 1095
# [LightGBM] [Info] Start training from score 818.795486
# submission_updated for ('Italy', 'Stickers for Less', 'Kaggle Tiers') hyperparameter
# 44
# ('Italy', 'Stickers for Less', 'Kerneler')
# submission_updated for ('Italy', 'Stickers for Less', 'Kerneler')
# 45
# ('Italy', 'Stickers for Less', 'Kerneler Dark Mode')
# submission_updated for ('Italy', 'Stickers for Less', 'Kerneler Dark Mode')
# 46
# ('Kenya', 'Discount Stickers', 'Holographic Goose')
# submission_updated for ('Kenya', 'Discount Stickers', 'Holographic Goose')
# 47
# ('Kenya', 'Discount Stickers', 'Kaggle')
# submission_updated for ('Kenya', 'Discount Stickers', 'Kaggle')
# 48
# ('Kenya', 'Discount Stickers', 'Kaggle Tiers')
# submission_updated for ('Kenya', 'Discount Stickers', 'Kaggle Tiers')
# 49
# ('Kenya', 'Discount Stickers', 'Kerneler')
# submission_updated for ('Kenya', 'Discount Stickers', 'Kerneler')
# 50
# ('Kenya', 'Discount Stickers', 'Kerneler Dark Mode')
# submission_updated for ('Kenya', 'Discount Stickers', 'Kerneler Dark Mode')
# 51
# ('Kenya', 'Premium Sticker Mart', 'Holographic Goose')
# submission_updated for ('Kenya', 'Premium Sticker Mart', 'Holographic Goose')
# 52
# ('Kenya', 'Premium Sticker Mart', 'Kaggle')
# submission_updated for ('Kenya', 'Premium Sticker Mart', 'Kaggle')
# 53
# ('Kenya', 'Premium Sticker Mart', 'Kaggle Tiers')
# submission_updated for ('Kenya', 'Premium Sticker Mart', 'Kaggle Tiers')
# 54
# ('Kenya', 'Premium Sticker Mart', 'Kerneler')
# submission_updated for ('Kenya', 'Premium Sticker Mart', 'Kerneler')
# 55
# ('Kenya', 'Premium Sticker Mart', 'Kerneler Dark Mode')
# submission_updated for ('Kenya', 'Premium Sticker Mart', 'Kerneler Dark Mode')
# 56
# ('Kenya', 'Stickers for Less', 'Holographic Goose')
# submission_updated for ('Kenya', 'Stickers for Less', 'Holographic Goose')
# 57
# ('Kenya', 'Stickers for Less', 'Kaggle')
# submission_updated for ('Kenya', 'Stickers for Less', 'Kaggle')
# 58
# ('Kenya', 'Stickers for Less', 'Kaggle Tiers')
# submission_updated for ('Kenya', 'Stickers for Less', 'Kaggle Tiers')
# 59
# ('Kenya', 'Stickers for Less', 'Kerneler')
# submission_updated for ('Kenya', 'Stickers for Less', 'Kerneler')
# 60
# ('Kenya', 'Stickers for Less', 'Kerneler Dark Mode')
# submission_updated for ('Kenya', 'Stickers for Less', 'Kerneler Dark Mode')
# 61
# ('Norway', 'Discount Stickers', 'Holographic Goose')
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.019819 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 151867
# [LightGBM] [Info] Number of data points in the train set: 1462, number of used features: 1095
# [LightGBM] [Info] Start training from score 178.287278
# submission_updated for ('Norway', 'Discount Stickers', 'Holographic Goose') hyperparameter
# 62
# ('Norway', 'Discount Stickers', 'Kaggle')
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.025845 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 279225
# [LightGBM] [Info] Number of data points in the train set: 1462, number of used features: 1095
# [LightGBM] [Info] Start training from score 1286.056088
# submission_updated for ('Norway', 'Discount Stickers', 'Kaggle') hyperparameter
# 63
# ('Norway', 'Discount Stickers', 'Kaggle Tiers')
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.025879 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 279225
# [LightGBM] [Info] Number of data points in the train set: 1462, number of used features: 1095
# [LightGBM] [Info] Start training from score 1055.303010
# submission_updated for ('Norway', 'Discount Stickers', 'Kaggle Tiers') hyperparameter
# 64
# ('Norway', 'Discount Stickers', 'Kerneler')
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.025148 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 279225
# [LightGBM] [Info] Number of data points in the train set: 1462, number of used features: 1095
# [LightGBM] [Info] Start training from score 575.936389
# submission_updated for ('Norway', 'Discount Stickers', 'Kerneler') hyperparameter
# 65
# ('Norway', 'Discount Stickers', 'Kerneler Dark Mode')
# submission_updated for ('Norway', 'Discount Stickers', 'Kerneler Dark Mode')
# 66
# ('Norway', 'Premium Sticker Mart', 'Holographic Goose')
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.025453 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 278911
# [LightGBM] [Info] Number of data points in the train set: 1462, number of used features: 1095
# [LightGBM] [Info] Start training from score 426.179207
# submission_updated for ('Norway', 'Premium Sticker Mart', 'Holographic Goose') hyperparameter
# 67
# ('Norway', 'Premium Sticker Mart', 'Kaggle')
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.024740 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 279225
# [LightGBM] [Info] Number of data points in the train set: 1462, number of used features: 1095
# [LightGBM] [Info] Start training from score 3058.445280
# submission_updated for ('Norway', 'Premium Sticker Mart', 'Kaggle') hyperparameter
# 68
# ('Norway', 'Premium Sticker Mart', 'Kaggle Tiers')
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.025570 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 279225
# [LightGBM] [Info] Number of data points in the train set: 1462, number of used features: 1095
# [LightGBM] [Info] Start training from score 2522.158003
# submission_updated for ('Norway', 'Premium Sticker Mart', 'Kaggle Tiers') hyperparameter
# 69
# ('Norway', 'Premium Sticker Mart', 'Kerneler')
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.025382 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 279225
# [LightGBM] [Info] Number of data points in the train set: 1462, number of used features: 1095
# [LightGBM] [Info] Start training from score 1376.266074
# submission_updated for ('Norway', 'Premium Sticker Mart', 'Kerneler') hyperparameter
# 70
# ('Norway', 'Premium Sticker Mart', 'Kerneler Dark Mode')
# submission_updated for ('Norway', 'Premium Sticker Mart', 'Kerneler Dark Mode')
# 71
# ('Norway', 'Stickers for Less', 'Holographic Goose')
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.025420 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 272279
# [LightGBM] [Info] Number of data points in the train set: 1462, number of used features: 1095
# [LightGBM] [Info] Start training from score 361.424077
# submission_updated for ('Norway', 'Stickers for Less', 'Holographic Goose') hyperparameter
# 72
# ('Norway', 'Stickers for Less', 'Kaggle')
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.025702 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 279225
# [LightGBM] [Info] Number of data points in the train set: 1462, number of used features: 1095
# [LightGBM] [Info] Start training from score 2594.556088
# submission_updated for ('Norway', 'Stickers for Less', 'Kaggle') hyperparameter
# 73
# ('Norway', 'Stickers for Less', 'Kaggle Tiers')
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.025451 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 279225
# [LightGBM] [Info] Number of data points in the train set: 1462, number of used features: 1095
# [LightGBM] [Info] Start training from score 2133.482900
# submission_updated for ('Norway', 'Stickers for Less', 'Kaggle Tiers') hyperparameter
# 74
# ('Norway', 'Stickers for Less', 'Kerneler')
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.026422 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 279225
# [LightGBM] [Info] Number of data points in the train set: 1462, number of used features: 1095
# [LightGBM] [Info] Start training from score 1168.290014
# submission_updated for ('Norway', 'Stickers for Less', 'Kerneler') hyperparameter
# 75
# ('Norway', 'Stickers for Less', 'Kerneler Dark Mode')
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.024937 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 279225
# [LightGBM] [Info] Number of data points in the train set: 1462, number of used features: 1095
# [LightGBM] [Info] Start training from score 1366.881669
# submission_updated for ('Norway', 'Stickers for Less', 'Kerneler Dark Mode') hyperparameter
# 76
# ('Singapore', 'Discount Stickers', 'Holographic Goose')
# submission_updated for ('Singapore', 'Discount Stickers', 'Holographic Goose')
# 77
# ('Singapore', 'Discount Stickers', 'Kaggle')
# submission_updated for ('Singapore', 'Discount Stickers', 'Kaggle')
# 78
# ('Singapore', 'Discount Stickers', 'Kaggle Tiers')
# submission_updated for ('Singapore', 'Discount Stickers', 'Kaggle Tiers')
# 79
# ('Singapore', 'Discount Stickers', 'Kerneler')
# submission_updated for ('Singapore', 'Discount Stickers', 'Kerneler')
# 80
# ('Singapore', 'Discount Stickers', 'Kerneler Dark Mode')
# submission_updated for ('Singapore', 'Discount Stickers', 'Kerneler Dark Mode')
# 81
# ('Singapore', 'Premium Sticker Mart', 'Holographic Goose')
# submission_updated for ('Singapore', 'Premium Sticker Mart', 'Holographic Goose')
# 82
# ('Singapore', 'Premium Sticker Mart', 'Kaggle')
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.025576 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 279225
# [LightGBM] [Info] Number of data points in the train set: 1462, number of used features: 1095
# [LightGBM] [Info] Start training from score 2022.095759
# submission_updated for ('Singapore', 'Premium Sticker Mart', 'Kaggle') hyperparameter
# 83
# ('Singapore', 'Premium Sticker Mart', 'Kaggle Tiers')
# submission_updated for ('Singapore', 'Premium Sticker Mart', 'Kaggle Tiers')
# 84
# ('Singapore', 'Premium Sticker Mart', 'Kerneler')
# submission_updated for ('Singapore', 'Premium Sticker Mart', 'Kerneler')
# 85
# ('Singapore', 'Premium Sticker Mart', 'Kerneler Dark Mode')
# submission_updated for ('Singapore', 'Premium Sticker Mart', 'Kerneler Dark Mode')
# 86
# ('Singapore', 'Stickers for Less', 'Holographic Goose')
# submission_updated for ('Singapore', 'Stickers for Less', 'Holographic Goose')
# 87
# ('Singapore', 'Stickers for Less', 'Kaggle')
# submission_updated for ('Singapore', 'Stickers for Less', 'Kaggle')
# 88
# ('Singapore', 'Stickers for Less', 'Kaggle Tiers')
# submission_updated for ('Singapore', 'Stickers for Less', 'Kaggle Tiers')
# 89
# ('Singapore', 'Stickers for Less', 'Kerneler')
# submission_updated for ('Singapore', 'Stickers for Less', 'Kerneler')
# 90
# ('Singapore', 'Stickers for Less', 'Kerneler Dark Mode')
# submission_updated for ('Singapore', 'Stickers for Less', 'Kerneler Dark Mode')
# submission_saved
